# %%
import pandas as pd

my_dataset = pd.read_csv(r"C:\Users\LOQ\Downloads\غسيل_الاموال_2.csv")
print("first 5 rows of the dataset: ")
print(my_dataset.head())
print("the shape of the dataset: ")
print(my_dataset.shape)
print("the dataset's info: ")
print(my_dataset.info())
print("the dataset's description: ")
print(my_dataset.describe())
print("Money Laundering Cases (1 = Yes, 0 = No):")
print(my_dataset['Is_laundering'].value_counts())
# Out:
# first 5 rows of the dataset:
#        Time        Date  Sender_account  Receiver_account   Amount  \
# 0   2:49:27   11/7/2022      5536444677        1050340186   757.14
# 1  17:57:33  10/12/2022      6381030298        9553458659    63.96
# 2  18:03:22  10/15/2022      3017645644        5803269369  1202.22
# 3  13:00:59   11/2/2022      6280994711         287481900   284.43
# 4  22:23:04  10/24/2022       796127945        3625053811  7146.01
#
#   Payment_currency Received_currency Sender_bank_location  \
# 0        UK pounds         UK pounds                   UK
# 1        UK pounds         UK pounds                   UK
# 2        UK pounds         UK pounds                   UK
# 3        UK pounds         UK pounds                   UK
# 4        UK pounds         UK pounds                   UK
#
#   Receiver_bank_location     Payment_type  Is_laundering  \
# 0                     UK      Credit card              0
# 1                     UK  Cash Withdrawal              1
# ...
